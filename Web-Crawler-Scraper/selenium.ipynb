# %%
# Generated by Selenium IDE
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

class TestTest1():
  def setup_method(self, method):
    self.driver = webdriver.Chrome()
    self.vars = {}
  
  def teardown_method(self, method):
    self.driver.quit()
  
  def test_test1(self):
    # Test name: test1
    # Step # | name | target | value | comment
    # 1 | open | /quote/TSLA/ |  | 
    self.driver.get("https://finance.yahoo.com/quote/TSLA/")
    # 2 | setWindowSize | 1552x880 |  | 
    self.driver.set_window_size(1552, 880)
    # 3 | click | css=.stx-holder:nth-child(22) > .stx-subholder |  | 
    self.driver.find_element(By.CSS_SELECTOR, ".stx-holder:nth-child(22) > .stx-subholder").click()
    # 4 | click | linkText=Chart |  | 
    self.driver.find_element(By.LINK_TEXT, "Chart").click()
    # 5 | click | css=.livePrice > span |  | 
    self.driver.find_element(By.CSS_SELECTOR, ".livePrice > span").click()
    # 6 | runScript | window.scrollTo(0,164) |  | 
    self.driver.execute_script("window.scrollTo(0,164)")
    # 7 | click | css=.nav-list |  | 
    self.driver.find_element(By.CSS_SELECTOR, ".nav-list").click()
    # 8 | click | linkText=Historical Data |  | 
    self.driver.find_element(By.LINK_TEXT, "Historical Data").click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 41
#      38     # 8 | click | linkText=Historical Data |  |
#      39     self.driver.find_element(By.LINK_TEXT, "Historical Data").click()
# ---> 41 test_test1()
#
# NameError: name 'test_test1' is not defined

# %%
#pip install selenium
